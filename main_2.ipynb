# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
from matplotlib.animation import FuncAnimation
from IPython.display import Image
import os
from scipy.sparse import csr_matrix

# %%
def CentNN(X, n_clusters, epsilon = 0.05):
    X =  np.where(np.isnan(X), 0, X)
    centroid_X = np.mean(X, axis=0)
    w = [centroid_X + epsilon, centroid_X - epsilon]
    cluster_members = [[], []]
    cluster_indices = []

    for i, x in enumerate(X):
        distances = cdist([x], w ,'euclidean')[0]
        index = np.argmin(distances)
        cluster_indices.append(index)
        w[index] = w[index] + 1/(1+len(cluster_members[index]))*(x - w[index])
        cluster_members[index].append(x)

    epoch = 0
    loser = 0
    while True:
        while True:
            loser = 0

            for i in range(len(X)):
                x = X[i]
                distances = cdist([x], w ,'euclidean')[0]
                current_cluster_index = np.argmin(distances)
                previous_cluster_index = cluster_indices[i]

                if previous_cluster_index != current_cluster_index: 
                    w[current_cluster_index] = w[current_cluster_index] + (x - w[current_cluster_index])/(len(cluster_members[current_cluster_index])+1)
                    w[previous_cluster_index] = w[previous_cluster_index] - (x - w[previous_cluster_index])/(len(cluster_members[previous_cluster_index])-1)   
                    cluster_members[current_cluster_index] = list(cluster_members[current_cluster_index])
                    cluster_members[current_cluster_index].append(x)

                    ind = 0
                    size = len(cluster_members[previous_cluster_index])
                    while ind != size and not np.array_equal(cluster_members[previous_cluster_index][ind],x):
                        ind += 1
                    if ind != size:
                        cluster_members[previous_cluster_index].pop(ind)
                    else:
                        raise ValueError('array not found in list.')

                    cluster_indices[i] = current_cluster_index
                    loser += 1
            if loser == 0:
                break

            epoch += 1

        if len(w) != n_clusters:
            all_error = []
            for i in range(len(w)):
                dists = cdist([w[i]], cluster_members[i], 'euclidean')[0]
                error = np.sum(dists)
                all_error.append(error)

            new_w = w[np.argmax(all_error)] + epsilon
            w.append(new_w)

            cluster_members.append(np.array([]))
        else:
            break
    
    return cluster_members, np.array(w)

# %%
def KMeans(X, n_clusters):
    X =  np.where(np.isnan(X), 0, X)
    centroids = [X[i] for i in random.sample(range(0, len(X)), n_clusters)]
    clusters = [[] for _ in range(n_clusters)]

    for x in X:
        min_dist = float('inf')
        closest_centroid = None
        for j, centroid in enumerate(centroids):
            dist = cdist([x], [x], 'euclidean')[0]
            if dist < min_dist:
                min_dist = dist
                closest_centroid = j
                
        clusters[closest_centroid].append(x)

    diff = 1
    iteration = 0
    while diff > 0 and iteration < 100:
        iteration += 1
        diff = 0
        centroids = [np.mean(cluster, axis=0) if cluster else random.choice(X) for cluster in clusters]
        new_clusters = [[] for _ in range(n_clusters)]

        for i, cluster in enumerate(clusters):
            for point in cluster:
                min_dist = float('inf')
                closest_centroid = None
                for j, centroid in enumerate(centroids):
                    dist = cdist([point], [centroid], 'euclidean')[0]
                    if dist < min_dist:
                        min_dist = dist
                        closest_centroid = j
                
                if closest_centroid != i:
                    diff += 1
                
                new_clusters[closest_centroid].append(point)
        
        clusters = new_clusters
    
    return clusters, centroids

# %%
def replace_quotes(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
        
        # Replace \" with ""
        modified_content = content.replace('\\"', '""')
        
        with open(file_path, 'w') as file:
            file.write(modified_content)
        
    except FileNotFoundError:
        print(f'File not found: {file_path}')
    except Exception as e:
        print(f'Error occurred: {e}')

# %%
def delete_book(ISBN_to_delete, ratings_df):
    return ratings_df[ratings_df['ISBN'] != ISBN_to_delete]

# %%
books_file = 'books-data/Books.csv'
users_file = 'books-data/Users.csv'
ratings_file = 'books-data/Book-Ratings.csv'

#replace_quotes(books_file)
books_df = pd.read_csv(books_file, encoding="ISO-8859-1", sep=";", on_bad_lines="skip", low_memory=False)
users_df = pd.read_csv(users_file, encoding="ISO-8859-1", sep=";")
ratings_df = pd.read_csv(ratings_file, encoding="ISO-8859-1", sep=";")
ratings_df = delete_book("0679781587", ratings_df)

min_user_ratings_values = [50, 100, 150]
min_book_ratings_values = [50, 100, 150]

user_counts = ratings_df['User-ID'].value_counts()
valid_users = user_counts[user_counts >= min_user_ratings_values[-1]].index.tolist()
selected_ratings_df = ratings_df[ratings_df['User-ID'].isin(valid_users)]

book_counts = selected_ratings_df['ISBN'].value_counts()
valid_books = book_counts[book_counts >= min_book_ratings_values[-1]].index.tolist()
selected_ratings_df = selected_ratings_df[selected_ratings_df['ISBN'].isin(valid_books)]

user_book_ratings = selected_ratings_df.pivot_table(index='User-ID', columns='ISBN', values='Book-Rating')

removed_rows = 0


def values_nan_or_zero(row):
    global removed_rows
    row = np.where(np.isnan(row), 0, row)
    if (row == 0).all():
        removed_rows += 1

    return not (row == 0).all()


user_book_ratings = user_book_ratings[user_book_ratings.apply(values_nan_or_zero, axis=1)]
users = np.random.choice(user_book_ratings.index, 10, replace=False)

print("Number of removed rows:", removed_rows)
for user in users:
    print(f"User id: {user}")

average_ratings = user_book_ratings.mean()

high_rated_books = average_ratings[average_ratings > 3]

high_rated_books_ISBNs = high_rated_books.index.tolist()

print("List of books with average rating greater than 3:")
for ISBN, rating in zip(high_rated_books_ISBNs, high_rated_books):
    book_title = books_df.loc[books_df['ISBN'] == ISBN, 'Book-Title'].values[0]
    print(f"ISBN: {ISBN} - Book Title: {book_title} - Average rating: {rating}")
# Out:
# Number of removed rows: 323
# User id: 140358
# User id: 120598
# User id: 265083
# User id: 253821
# User id: 83637
# User id: 145165
# User id: 200226
# User id: 28523
# User id: 108352
# User id: 236058
# List of books with average rating greater than 3:
# ISBN: 0142001740 - Book Title: The Secret Life of Bees - Average rating: 3.186335403726708
# ISBN: 0156027321 - Book Title: Life of Pi - Average rating: 3.2
# ISBN: 0312195516 - Book Title: The Red Tent (Bestselling Backlist) - Average rating: 3.3551912568306013
# ISBN: 0316666343 - Book Title: The Lovely Bones: A Novel - Average rating: 3.699324324324324
# ISBN: 0345337662 - Book Title: Interview with the Vampire - Average rating: 3.1055900621118013
# ISBN: 0385335482 - Book Title: Confessions of a Shopaholic (Summer Display Opportunity) - Average rating: 3.0220588235294117
# ISBN: 0385504209 - Book Title: The Da Vinci Code - Average rating: 3.6666666666666665
# ISBN: 0440213525 - Book Title: The Client - Average rating: 3.015267175572519
# ISBN: 0446310786 - Book Title: To Kill a Mockingbird - Average rating: 4.649253731343284
# ISBN: 0446610038 - Book Title: 1st to Die: A Novel - Average rating: 3.225806451612903
# ISBN: 0446672211 - Book Title: Where the Heart Is (Oprah's Book Club (Paperback)) - Average rating: 3.371584699453552
# ISBN: 0452282152 - Book Title: Girl with a Pearl Earring - Average rating: 3.4274193548387095
# ISBN: 059035342X - Book Title: Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback)) - Average rating: 4.03030303030303
# ISBN: 0743418174 - Book Title: Good in Bed - Average rating: 3.136094674556213

# %%
def get_pivot_table(min_user_ratings, min_book_ratings):
    user_counts = ratings_df['User-ID'].value_counts()
    valid_users = user_counts[user_counts >= min_user_ratings].index.tolist()
    selected_ratings_df = ratings_df[ratings_df['User-ID'].isin(valid_users)]

    book_counts = selected_ratings_df['ISBN'].value_counts()
    valid_books = book_counts[book_counts >= min_book_ratings].index.tolist()
    selected_ratings_df = selected_ratings_df[selected_ratings_df['ISBN'].isin(valid_books)]
    
    user_book_ratings = selected_ratings_df.pivot_table(index='User-ID', columns='ISBN', values='Book-Rating')
    
    def values_nan_or_zero(row):
        row = np.where(np.isnan(row), 0, row)
        return not (row == 0).all()

    user_book_ratings = user_book_ratings[user_book_ratings.apply(values_nan_or_zero, axis=1)]

    return user_book_ratings

# %%
def make_recommendation(centroids):
    user_recommendations = {}    

    for user_id in users:
        print(f"User {user_id}:")

        user_ratings = user_book_ratings.loc[user_id].values.reshape(1, -1)

        nan_ratings = np.isnan(user_ratings)
        nan_indices = np.where(nan_ratings)[1]

        user_ratings_without_nan = np.where(np.isnan(user_ratings), 0, user_ratings)

        closest_centroid = None
        min_dist = float('inf')
        index = 0
        for i, centroid in enumerate(centroids):
            dist = cdist(user_ratings_without_nan, np.array([centroid]), 'euclidean')[0]
            if dist < min_dist:
                min_dist = dist
                closest_centroid = centroid
                index = i
        print("Closest centroid: ", index)
        
        recommended_books_rating = np.array([])
        recommended_books_ISBN = np.array([])
        for index in nan_indices:
            if user_book_ratings.columns[index] in high_rated_books_ISBNs:
                recommended_books_rating = np.append(recommended_books_rating, closest_centroid[index])
                recommended_books_ISBN = np.append(recommended_books_ISBN, user_book_ratings.columns[index])

        sorted_indices = np.argsort(recommended_books_rating)[::-1]

        sorted_recommended_books_rating = recommended_books_rating[sorted_indices]
        sorted_recommended_books_ISBN = recommended_books_ISBN[sorted_indices]

        best_books_rating = sorted_recommended_books_rating[:10]
        best_books_ISBN = sorted_recommended_books_ISBN[:10]
            
        best_books_names = np.array([])
        for ISBN in best_books_ISBN:
            best_books_names = np.append(best_books_names, books_df[books_df['ISBN'] == ISBN].values[0][1])

        print(';\n'.join(str(b) for b in best_books_names))

        user_recommendations[user_id] = {'best_books_rating': best_books_rating, 'best_books_names': best_books_names}
    
    return user_recommendations

# %%
def plot_all_recommendations(all_recommendations):
    users = list(all_recommendations[(min_user_ratings_values[0], min_book_ratings_values[0])].keys())
    sets = list(all_recommendations.keys())
    ratings = [all_recommendations[s][user]['best_books_rating'] for s in sets for user in users]
    books = [all_recommendations[s][user]['best_books_names'] for s in sets for user in users]

    unique_books = list(set([book for sublist in books for book in sublist]))
    cm = plt.get_cmap('gist_rainbow')
    colors = [cm(1.*i/len(unique_books)) for i in range(len(unique_books))]
    book_color_map = {book: color for book, color in zip(unique_books, colors)}

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.set_ylabel('(min_user_ratings, min_book_ratings)')
    ax.set_zlabel('Rating (0-10)')

    ax.set_xticks(range(len(sets)))
    ax.set_xticklabels(sets)

    ax.set_yticks(range(len(users)))
    ax.set_yticklabels(users)

    books_ratings = [(book, user_data['best_books_rating']) for s in all_recommendations for user_data in all_recommendations[s].values() for book in user_data['best_books_names']]
    ratings_data = [rating for _, ratings in books_ratings for rating in ratings]

    ax.set_zlim(0, 10)
    ax.set_zticks(np.linspace(0, 10, 11))
    ax.set_zticklabels(np.linspace(0, 10, 11))

    for x, (set_val, users_data) in enumerate(all_recommendations.items()):
        for y, (user, user_data) in enumerate(users_data.items()):
            names, ratings = user_data['best_books_names'], user_data['best_books_rating']
            for name, rating in zip(names, ratings):
                ax.scatter(x, y, rating, color=book_color_map[name])

    plt.show()

# %%
def plot_recommendations_for_users(all_recommendations):
    users = list(all_recommendations[(min_user_ratings_values[0], min_book_ratings_values[0])].keys())
    sets = list(all_recommendations.keys())
    ratings = [all_recommendations[s][user]['best_books_rating'] for s in sets for user in users]
    books = [all_recommendations[s][user]['best_books_names'] for s in sets for user in users]

    unique_books = list(set(book for users_data in all_recommendations.values() for user_data in users_data.values() for book in user_data['best_books_names']))
    colors = cm.rainbow(np.linspace(0, 1, len(unique_books)))
    book_color_map = {book: color for book, color in zip(unique_books, colors)}

    fig, axs = plt.subplots(len(users), 1, figsize=(8, 6 * len(users)))

    for user_index, user in enumerate(users):
        for set_val_index, set_val in enumerate(sets):
            x_val = set_val_index + 1 
            ratings = all_recommendations[set_val][user]['best_books_rating']
            names = all_recommendations[set_val][user]['best_books_names']

            for book_index, (rating, name) in enumerate(zip(ratings, names)):
                axs[user_index].scatter(x_val, rating, color=book_color_map[name], label=name)

            axs[user_index].set_title(f'Ratings for User {user}')
            axs[user_index].set_ylabel('Rating (0-10)')
            axs[user_index].set_xlabel('Sets (min_user_rating, min_book_rating)')
            axs[user_index].set_xticks(range(1, len(sets) + 1))
            axs[user_index].set_xticklabels([f"({s[0]}, {s[1]})" for s in sets], rotation=45, ha='right')
            axs[user_index].set_ylim(-0.5, 11)
            
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.show()

# %%
def plot_recommendations_for_sets(all_recommendations):
    users = list(all_recommendations[(min_user_ratings_values[0], min_book_ratings_values[0])].keys())
    sets = list(all_recommendations.keys())
    unique_books = list(set(book for users_data in all_recommendations.values() for user_data in users_data.values() for book in user_data['best_books_names']))
    colors = plt.cm.rainbow(np.linspace(0, 1, len(unique_books)))
    book_color_map = {book: color for book, color in zip(unique_books, colors)}

    fig, axs = plt.subplots(len(sets), 1, figsize=(8, 6 * len(sets)))

    for set_index, set_val in enumerate(sets):
        for user_index, user in enumerate(users):
            ratings = all_recommendations[set_val][user]['best_books_rating']
            names = all_recommendations[set_val][user]['best_books_names']

            x_vals = np.full(len(ratings), user_index + 1)
            y_vals = ratings

            for x_val, y_val, name in zip(x_vals, y_vals, names):
                axs[set_index].scatter(x_val, y_val, color=book_color_map[name], label=name)

            axs[set_index].set_title(f'Ratings for Set {set_val}')
            axs[set_index].set_ylabel('Rating (0-10)')
            axs[set_index].set_xlabel('Users')
            axs[set_index].set_xticks(range(1, len(users) + 1))
            axs[set_index].set_xticklabels(users)
            axs[set_index].set_ylim(-0.5, 11)

    plt.subplots_adjust(top=0.92)
    plt.show()

# %%
all_recommendations_kmeans = {}
all_clusters_kmeans = {}

for min_user_ratings in min_user_ratings_values:
    for min_book_ratings in min_book_ratings_values:
        print(f"\nPredictions for min_user_ratings = {min_user_ratings}, min_book_ratings = {min_book_ratings}\n")
        user_book_ratings = get_pivot_table(min_user_ratings, min_book_ratings)
        print(user_book_ratings)
        clusters, centroids = KMeans(user_book_ratings, 100)
        all_clusters_kmeans[(min_user_ratings, min_book_ratings)] = (clusters, centroids)
        recommendations = make_recommendation(centroids)

        all_recommendations_kmeans[(min_user_ratings, min_book_ratings)] = recommendations
# Out:
# Predictions for min_user_ratings = 50, min_book_ratings = 50
# ISBN     002026478X  002542730X  0060008032  0060085444  0060096195  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 643             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# ISBN     006016848X  0060173289  0060175400  006019491X  0060199652  ...  \
# User-ID                                                              ...
# 243             NaN         NaN         NaN         NaN         NaN  ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 507             NaN         NaN         NaN         NaN         NaN  ...
# 638             NaN         NaN         NaN         NaN         NaN  ...
# 643             NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          0.0         NaN         NaN         NaN         NaN  ...
# 278582          NaN         NaN         NaN         NaN         NaN  ...
# 278633          NaN         NaN         NaN         NaN         NaN  ...
# 278843          NaN         9.0         NaN         NaN         NaN  ...
#
# ISBN     1565122968  1573225517  1573225789  1573229326  1573229571  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 643             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# ISBN     1573229725  1576737330  1592400876  1878424319  1885171080
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 643             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# [2837 rows x 1107 columns]
# User 140358:
# Closest centroid:  67
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Secret Life of Bees;
# To Kill a Mockingbird;
# Girl with a Pearl Earring;
# The Da Vinci Code;
# The Red Tent (Bestselling Backlist);
# The Lovely Bones: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# Good in Bed
# User 120598:
# Closest centroid:  40
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Interview with the Vampire;
# Life of Pi;
# To Kill a Mockingbird;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# The Client;
# Good in Bed
# User 265083:
# Closest centroid:  40
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Interview with the Vampire;
# To Kill a Mockingbird;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# The Client;
# Good in Bed;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 253821:
# Closest centroid:  0
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Good in Bed;
# The Client;
# Life of Pi;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist)
# User 83637:
# Closest centroid:  52
# Where the Heart Is (Oprah's Book Club (Paperback));
# To Kill a Mockingbird;
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client;
# 1st to Die: A Novel;
# Girl with a Pearl Earring;
# Interview with the Vampire
# User 145165:
# Closest centroid:  28
# The Secret Life of Bees;
# The Da Vinci Code;
# Good in Bed;
# The Lovely Bones: A Novel;
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# The Red Tent (Bestselling Backlist);
# Confessions of a Shopaholic (Summer Display Opportunity);
# Where the Heart Is (Oprah's Book Club (Paperback));
# Life of Pi
# User 200226:
# Closest centroid:  68
# The Da Vinci Code;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Secret Life of Bees;
# Life of Pi;
# The Client;
# Interview with the Vampire
# User 28523:
# Closest centroid:  40
# The Secret Life of Bees;
# Interview with the Vampire;
# Life of Pi;
# To Kill a Mockingbird;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# The Client;
# Good in Bed;
# The Da Vinci Code
# User 108352:
# Closest centroid:  11
# The Da Vinci Code;
# The Lovely Bones: A Novel;
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# The Client;
# Good in Bed;
# 1st to Die: A Novel
# User 236058:
# Closest centroid:  80
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Interview with the Vampire;
# Life of Pi;
# Good in Bed;
# The Da Vinci Code;
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Client
#
# Predictions for min_user_ratings = 50, min_book_ratings = 100
# ISBN     002542730X  0060391626  0060392452  0060502258  0060915544  \
# User-ID
# 243             NaN         NaN         NaN         NaN        10.0
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         0.0         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         0.0         0.0
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0060928336  0060930535  0060934417  0060938455  0060976845  ...  \
# User-ID                                                              ...
# 243             NaN         NaN         NaN         NaN         NaN  ...
# 254             NaN         0.0         NaN         NaN         NaN  ...
# 507             NaN         NaN         0.0         0.0         NaN  ...
# 638             NaN         NaN         NaN         NaN         NaN  ...
# 882             NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          NaN         NaN         NaN         NaN         NaN  ...
# 278582          NaN         NaN         NaN         NaN         NaN  ...
# 278633          NaN         NaN         NaN         NaN         NaN  ...
# 278843          NaN         NaN         NaN         NaN         0.0  ...
#
# ISBN     0842329129  0842329218  0971880107  1400031354  1400034779  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN        10.0
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# ISBN     155874262X  1558743669  1559029838  1573225789  1573229326
# User-ID
# 243             5.0         NaN         NaN         NaN         NaN
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         0.0         NaN         NaN
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# [2515 rows x 304 columns]
# User 140358:
# Closest centroid:  35
# The Lovely Bones: A Novel;
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# Good in Bed;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# The Client;
# Where the Heart Is (Oprah's Book Club (Paperback))
# User 120598:
# Closest centroid:  59
# To Kill a Mockingbird;
# The Client;
# Interview with the Vampire;
# The Da Vinci Code;
# The Secret Life of Bees;
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring
# User 265083:
# Closest centroid:  27
# The Lovely Bones: A Novel;
# To Kill a Mockingbird;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Secret Life of Bees;
# Good in Bed;
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# User 253821:
# Closest centroid:  65
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# 1st to Die: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Life of Pi;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Secret Life of Bees;
# The Client;
# Girl with a Pearl Earring;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# User 83637:
# Closest centroid:  0
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# Good in Bed;
# To Kill a Mockingbird;
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# Girl with a Pearl Earring;
# The Client;
# Life of Pi;
# The Secret Life of Bees
# User 145165:
# Closest centroid:  0
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# Good in Bed;
# To Kill a Mockingbird;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# The Lovely Bones: A Novel;
# The Client;
# The Da Vinci Code
# User 200226:
# Closest centroid:  37
# The Secret Life of Bees;
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client;
# The Da Vinci Code;
# Life of Pi
# User 28523:
# Closest centroid:  42
# To Kill a Mockingbird;
# The Da Vinci Code;
# Good in Bed;
# The Client;
# Girl with a Pearl Earring;
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Red Tent (Bestselling Backlist)
# User 108352:
# Closest centroid:  55
# The Da Vinci Code;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Secret Life of Bees;
# Girl with a Pearl Earring;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client;
# Interview with the Vampire
# User 236058:
# Closest centroid:  35
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# Good in Bed;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Girl with a Pearl Earring;
# The Client;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
#
# Predictions for min_user_ratings = 50, min_book_ratings = 150
# ISBN     0060392452  0060502258  0060928336  0060930535  0060934417  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             NaN         NaN         NaN         0.0         NaN
# 507             0.0         NaN         NaN         NaN         0.0
# 638             NaN         NaN         NaN         NaN         NaN
# 882             NaN         0.0         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0060938455  0060976845  0060987103  0061009059  006101351X  ...  \
# User-ID                                                              ...
# 243             NaN         NaN         NaN         NaN         NaN  ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 507             0.0         NaN         NaN         NaN         NaN  ...
# 638             NaN         NaN         NaN         NaN         NaN  ...
# 882             NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          NaN         NaN         NaN         NaN         NaN  ...
# 278582          NaN         NaN         NaN         NaN         NaN  ...
# 278633          NaN         NaN         NaN         NaN         NaN  ...
# 278843          NaN         0.0         NaN         NaN         NaN  ...
#
# ISBN     068484477X  0684872153  0743418174  0786868716  080410526X  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             NaN         0.0         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         0.0
# 278582          NaN         NaN         NaN         NaN         NaN
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0804106304  080410753X  0842329129  0971880107  1400034779
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 254             0.0         0.0         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 638             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
# 278582          NaN         NaN         NaN         NaN        10.0
# 278633          NaN         NaN         NaN         NaN         NaN
# 278843          0.0         NaN         NaN         NaN         NaN
#
# [2186 rows x 115 columns]
# User 140358:
# Closest centroid:  81
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Client;
# The Da Vinci Code;
# 1st to Die: A Novel;
# The Lovely Bones: A Novel;
# Good in Bed;
# The Red Tent (Bestselling Backlist);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# To Kill a Mockingbird
# User 120598:
# Closest centroid:  59
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# The Secret Life of Bees;
# The Lovely Bones: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# To Kill a Mockingbird;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# The Client
# User 265083:
# Closest centroid:  76
# The Lovely Bones: A Novel;
# The Da Vinci Code;
# To Kill a Mockingbird;
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Secret Life of Bees;
# Good in Bed;
# 1st to Die: A Novel;
# The Client
# User 253821:
# Closest centroid:  68
# The Secret Life of Bees;
# Life of Pi;
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Good in Bed;
# The Red Tent (Bestselling Backlist)
# User 83637:
# Closest centroid:  60
# Interview with the Vampire;
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client;
# 1st to Die: A Novel;
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# Life of Pi;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback))
# User 145165:
# Closest centroid:  60
# Interview with the Vampire;
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# The Da Vinci Code;
# Life of Pi;
# Girl with a Pearl Earring
# User 200226:
# Closest centroid:  70
# The Da Vinci Code;
# The Secret Life of Bees;
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Interview with the Vampire;
# Life of Pi
# User 28523:
# Closest centroid:  67
# The Client;
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 108352:
# Closest centroid:  61
# The Lovely Bones: A Novel;
# Good in Bed;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Interview with the Vampire;
# Confessions of a Shopaholic (Summer Display Opportunity);
# To Kill a Mockingbird;
# The Client;
# The Red Tent (Bestselling Backlist);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# User 236058:
# Closest centroid:  52
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Client;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist);
# Life of Pi
#
# Predictions for min_user_ratings = 100, min_book_ratings = 50
# ISBN     002542730X  0060008032  0060085444  0060096195  006016848X  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 277427         10.0         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         0.0
#
# ISBN     0060175400  0060199652  0060391626  0060392452  0060502258  ...  \
# User-ID                                                              ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 507             NaN         NaN         NaN         0.0         NaN  ...
# 882             NaN         NaN         NaN         NaN         0.0  ...
# 1424            NaN         NaN         NaN         NaN         NaN  ...
# 1435            NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 277427          NaN         NaN         NaN         NaN         NaN  ...
# 277639          NaN         NaN         NaN         NaN         NaN  ...
# 278137          NaN         NaN         NaN         NaN         NaN  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     1558743669  1558744150  1558744630  1558745157  1559029838  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         9.0         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         0.0
#
# ISBN     1573225789  1573229326  1573229725  1592400876  1878424319
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# [1609 rows x 842 columns]
# User 140358:
# Closest centroid:  99
# The Client;
# The Da Vinci Code;
# To Kill a Mockingbird;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Girl with a Pearl Earring;
# The Lovely Bones: A Novel;
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees
# User 120598:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# The Da Vinci Code;
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# Good in Bed
# User 265083:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# The Da Vinci Code;
# The Red Tent (Bestselling Backlist);
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# To Kill a Mockingbird;
# Good in Bed;
# The Client
# User 253821:
# Closest centroid:  0
# The Red Tent (Bestselling Backlist);
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# Good in Bed;
# The Client;
# 1st to Die: A Novel
# User 83637:
# Closest centroid:  0
# The Red Tent (Bestselling Backlist);
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# Good in Bed;
# The Client
# User 145165:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# The Da Vinci Code;
# The Red Tent (Bestselling Backlist);
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# To Kill a Mockingbird
# User 200226:
# Closest centroid:  85
# The Secret Life of Bees;
# Interview with the Vampire;
# The Da Vinci Code;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client;
# Life of Pi
# User 28523:
# Closest centroid:  0
# The Da Vinci Code;
# The Red Tent (Bestselling Backlist);
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# Good in Bed
# User 108352:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# The Da Vinci Code;
# The Red Tent (Bestselling Backlist);
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# To Kill a Mockingbird;
# Good in Bed
# User 236058:
# Closest centroid:  0
# The Da Vinci Code;
# The Red Tent (Bestselling Backlist);
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# Good in Bed;
# The Client
#
# Predictions for min_user_ratings = 100, min_book_ratings = 100
# ISBN     002542730X  0060392452  0060502258  0060915544  0060928336  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         0.0         NaN         NaN         NaN
# 882             NaN         NaN         0.0         0.0         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            NaN         NaN         NaN        10.0         NaN
# ...             ...         ...         ...         ...         ...
# 277427         10.0         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0060930535  0060934417  0060938455  0060976845  0060987103  ...  \
# User-ID                                                              ...
# 254             0.0         NaN         NaN         NaN         NaN  ...
# 507             NaN         0.0         0.0         NaN         NaN  ...
# 882             NaN         NaN         NaN         NaN         NaN  ...
# 1424            7.0         NaN         NaN         NaN         NaN  ...
# 1435            NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 277427          0.0         0.0         NaN         NaN         NaN  ...
# 277639          NaN         NaN         NaN         NaN         NaN  ...
# 278137          NaN         NaN         NaN         NaN         NaN  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     0804114986  080411868X  0805063897  0842329129  0842329218  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             0.0         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0971880107  1400031354  1400034779  1558743669  1559029838
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            5.0         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 277427          0.0         0.0         0.0         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          0.0         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         0.0
#
# [1440 rows x 195 columns]
# User 140358:
# Closest centroid:  43
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Client;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Lovely Bones: A Novel
# User 120598:
# Closest centroid:  26
# To Kill a Mockingbird;
# The Secret Life of Bees;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# The Client;
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Lovely Bones: A Novel;
# Good in Bed
# User 265083:
# Closest centroid:  67
# To Kill a Mockingbird;
# The Secret Life of Bees;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Lovely Bones: A Novel;
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# Good in Bed;
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# User 253821:
# Closest centroid:  21
# The Secret Life of Bees;
# 1st to Die: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Life of Pi;
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# User 83637:
# Closest centroid:  25
# The Secret Life of Bees;
# Interview with the Vampire;
# Girl with a Pearl Earring;
# The Client;
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# Good in Bed;
# Life of Pi;
# The Red Tent (Bestselling Backlist);
# Where the Heart Is (Oprah's Book Club (Paperback))
# User 145165:
# Closest centroid:  57
# The Secret Life of Bees;
# The Lovely Bones: A Novel;
# To Kill a Mockingbird;
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Client
# User 200226:
# Closest centroid:  77
# The Client;
# The Da Vinci Code;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Interview with the Vampire;
# Life of Pi;
# The Secret Life of Bees
# User 28523:
# Closest centroid:  36
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# The Client;
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire
# User 108352:
# Closest centroid:  25
# The Secret Life of Bees;
# Interview with the Vampire;
# Girl with a Pearl Earring;
# The Client;
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# The Da Vinci Code
# User 236058:
# Closest centroid:  21
# The Secret Life of Bees;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# The Da Vinci Code;
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Life of Pi;
# Interview with the Vampire;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
#
# Predictions for min_user_ratings = 100, min_book_ratings = 150
# ISBN     0060502258  0060928336  0060930535  0060976845  0060987103  \
# User-ID
# 254             NaN         NaN         0.0         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             0.0         NaN         NaN         NaN         NaN
# 1424            NaN         NaN         7.0         NaN         NaN
# 1435            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276925          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         0.0         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
#
# ISBN     006101351X  0140293248  0142001740  0156027321  0312195516  ...  \
# User-ID                                                              ...
# 254             NaN         NaN         9.0         NaN         NaN  ...
# 507             NaN         NaN        10.0         NaN         NaN  ...
# 882             NaN         NaN         NaN         NaN         0.0  ...
# 1424            NaN         NaN         NaN         NaN         NaN  ...
# 1435            NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 276925          NaN         NaN         NaN         NaN         NaN  ...
# 277427          NaN         NaN         0.0         NaN         NaN  ...
# 277639          NaN         NaN         NaN         NaN         NaN  ...
# 278137          NaN         NaN         NaN         NaN         0.0  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     0671021001  0671027360  067976402X  068484477X  0743418174  \
# User-ID
# 254             7.0         NaN         0.0         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN        10.0         NaN         NaN
# 1424            NaN         NaN         NaN         NaN         NaN
# 1435            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276925          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0786868716  080410526X  0804106304  0971880107  1400034779
# User-ID
# 254             NaN         NaN         0.0         NaN         NaN
# 507             NaN         NaN         NaN         NaN         NaN
# 882             NaN         NaN         NaN         NaN         NaN
# 1424            0.0         NaN         6.0         NaN         NaN
# 1435            NaN         NaN         NaN         5.0         NaN
# ...             ...         ...         ...         ...         ...
# 276925          NaN         NaN         0.0         0.0         NaN
# 277427          NaN         NaN         NaN         0.0         0.0
# 277639          NaN         NaN         NaN         NaN         NaN
# 278137          NaN         NaN         8.0         0.0         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
#
# [1227 rows x 73 columns]
# User 140358:
# Closest centroid:  74
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Lovely Bones: A Novel;
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# To Kill a Mockingbird
# User 120598:
# Closest centroid:  44
# Where the Heart Is (Oprah's Book Club (Paperback));
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Lovely Bones: A Novel;
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# Interview with the Vampire;
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# The Client
# User 265083:
# Closest centroid:  69
# The Lovely Bones: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Interview with the Vampire;
# 1st to Die: A Novel;
# The Client;
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# To Kill a Mockingbird;
# The Da Vinci Code
# User 253821:
# Closest centroid:  50
# Life of Pi;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Red Tent (Bestselling Backlist);
# 1st to Die: A Novel;
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Client;
# Interview with the Vampire
# User 83637:
# Closest centroid:  20
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# The Client;
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# The Secret Life of Bees;
# Life of Pi;
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback))
# User 145165:
# Closest centroid:  13
# The Da Vinci Code;
# Girl with a Pearl Earring;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# To Kill a Mockingbird;
# Interview with the Vampire;
# The Lovely Bones: A Novel
# User 200226:
# Closest centroid:  50
# Life of Pi;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client;
# The Da Vinci Code;
# Interview with the Vampire;
# The Secret Life of Bees
# User 28523:
# Closest centroid:  70
# Confessions of a Shopaholic (Summer Display Opportunity);
# Good in Bed;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Client;
# The Da Vinci Code;
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist)
# User 108352:
# Closest centroid:  20
# Confessions of a Shopaholic (Summer Display Opportunity);
# 1st to Die: A Novel;
# The Client;
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# The Secret Life of Bees;
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Where the Heart Is (Oprah's Book Club (Paperback))
# User 236058:
# Closest centroid:  49
# The Red Tent (Bestselling Backlist);
# Life of Pi;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Interview with the Vampire;
# The Secret Life of Bees;
# The Da Vinci Code;
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client
#
# Predictions for min_user_ratings = 150, min_book_ratings = 50
# ISBN     002542730X  0060008032  0060096195  006016848X  0060391626  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 1733            NaN         NaN         NaN         NaN         NaN
# 1903            NaN         NaN         NaN         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427         10.0         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         0.0         NaN
#
# ISBN     0060392452  0060502258  0060915544  0060921145  0060922532  ...  \
# User-ID                                                              ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 1733            NaN         NaN         NaN         NaN         NaN  ...
# 1903            0.0         NaN         NaN         NaN         NaN  ...
# 2033            NaN         NaN         NaN         NaN         NaN  ...
# 2110            NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 276680          NaN         NaN         NaN         NaN         NaN  ...
# 277427          NaN         NaN         NaN         NaN         NaN  ...
# 277639          NaN         NaN         NaN         NaN         NaN  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     1401088945  155874262X  1558743669  1558744150  1558745157  \
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 1733            NaN         NaN         NaN         NaN         NaN
# 1903            NaN         NaN         NaN         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# ISBN     1559029838  1573225789  1573229326  1573229725  1592400876
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 1733            NaN         NaN         NaN         NaN         NaN
# 1903            NaN         NaN         NaN         NaN         0.0
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          0.0         NaN         NaN         NaN         NaN
#
# [1115 rows x 661 columns]
# User 140358:
# Closest centroid:  20
# The Client;
# The Lovely Bones: A Novel;
# 1st to Die: A Novel;
# The Da Vinci Code;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# To Kill a Mockingbird;
# Good in Bed;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Life of Pi;
# Where the Heart Is (Oprah's Book Club (Paperback))
# User 120598:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Good in Bed;
# Interview with the Vampire;
# Life of Pi;
# To Kill a Mockingbird;
# Girl with a Pearl Earring;
# 1st to Die: A Novel
# User 265083:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# To Kill a Mockingbird;
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 253821:
# Closest centroid:  0
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# Life of Pi;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 83637:
# Closest centroid:  0
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# Life of Pi;
# To Kill a Mockingbird;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 145165:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# Life of Pi;
# To Kill a Mockingbird;
# Girl with a Pearl Earring
# User 200226:
# Closest centroid:  68
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client;
# Interview with the Vampire;
# The Da Vinci Code;
# Life of Pi;
# The Secret Life of Bees
# User 28523:
# Closest centroid:  0
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# Life of Pi;
# To Kill a Mockingbird;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 108352:
# Closest centroid:  0
# The Lovely Bones: A Novel;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# To Kill a Mockingbird;
# Girl with a Pearl Earring;
# 1st to Die: A Novel
# User 236058:
# Closest centroid:  0
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Secret Life of Bees;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Good in Bed;
# Interview with the Vampire;
# Life of Pi;
# Girl with a Pearl Earring;
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client
#
# Predictions for min_user_ratings = 150, min_book_ratings = 100
# ISBN     0060502258  0060928336  0060930535  0060934417  0060938455  \
# User-ID
# 254             NaN         NaN         0.0         NaN         NaN
# 1733            NaN         NaN         NaN         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         0.0         0.0         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0060976845  0060987103  0060987529  0061009059  006101351X  ...  \
# User-ID                                                              ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 1733            NaN         NaN         NaN         NaN         NaN  ...
# 2033            NaN         NaN         NaN         NaN         NaN  ...
# 2110            NaN         NaN         7.0         NaN         NaN  ...
# 2276            NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 276680          NaN         NaN         NaN         NaN         NaN  ...
# 277427          NaN         NaN         NaN         9.0         NaN  ...
# 277639          NaN         NaN         NaN         NaN         NaN  ...
# 278188          NaN         NaN         NaN         NaN         NaN  ...
# 278418          NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     080410526X  0804106304  080410753X  080411109X  080411868X  \
# User-ID
# 254             NaN         0.0         0.0         NaN         NaN
# 1733            NaN         NaN         NaN         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         0.0         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          0.0         NaN         NaN         NaN         NaN
#
# ISBN     0805063897  0842329129  0971880107  1400034779  1558743669
# User-ID
# 254             NaN         NaN         NaN         NaN         NaN
# 1733            NaN         NaN         1.0         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# 2276           10.0         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         0.0         0.0         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
# 278418          NaN         NaN         NaN         NaN         NaN
#
# [975 rows x 137 columns]
# User 140358:
# Closest centroid:  30
# To Kill a Mockingbird;
# The Client;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Da Vinci Code;
# 1st to Die: A Novel;
# The Red Tent (Bestselling Backlist);
# Girl with a Pearl Earring;
# Life of Pi;
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# User 120598:
# Closest centroid:  0
# The Secret Life of Bees;
# Life of Pi;
# To Kill a Mockingbird;
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# The Client;
# 1st to Die: A Novel;
# Girl with a Pearl Earring;
# The Lovely Bones: A Novel
# User 265083:
# Closest centroid:  0
# The Secret Life of Bees;
# To Kill a Mockingbird;
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# The Client;
# 1st to Die: A Novel;
# The Red Tent (Bestselling Backlist);
# The Lovely Bones: A Novel;
# The Da Vinci Code
# User 253821:
# Closest centroid:  98
# The Client;
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# The Secret Life of Bees;
# Good in Bed;
# Life of Pi;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# 1st to Die: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 83637:
# Closest centroid:  0
# The Secret Life of Bees;
# Life of Pi;
# To Kill a Mockingbird;
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# The Client;
# 1st to Die: A Novel;
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist)
# User 145165:
# Closest centroid:  0
# The Secret Life of Bees;
# Life of Pi;
# To Kill a Mockingbird;
# Interview with the Vampire;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# The Client;
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# The Lovely Bones: A Novel
# User 200226:
# Closest centroid:  44
# The Client;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Da Vinci Code;
# The Secret Life of Bees;
# Interview with the Vampire;
# Life of Pi
# User 28523:
# Closest centroid:  31
# The Red Tent (Bestselling Backlist);
# The Secret Life of Bees;
# Girl with a Pearl Earring;
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Client;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 108352:
# Closest centroid:  95
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Client;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire
# User 236058:
# Closest centroid:  26
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Girl with a Pearl Earring;
# The Red Tent (Bestselling Backlist);
# Confessions of a Shopaholic (Summer Display Opportunity);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client;
# The Da Vinci Code;
# Interview with the Vampire;
# Life of Pi
#
# Predictions for min_user_ratings = 150, min_book_ratings = 150
# ISBN     0060928336  0060930535  0060976845  006101351X  0142001740  \
# User-ID
# 254             NaN         0.0         NaN         NaN         9.0
# 1733            NaN         NaN         NaN         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 275970          0.0         NaN         NaN         NaN         NaN
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         0.0         NaN         NaN         0.0
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
#
# ISBN     0156027321  0312195516  0312278586  0316601950  0316666343  ...  \
# User-ID                                                              ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 1733            NaN         NaN         NaN         NaN         NaN  ...
# 2033            NaN         NaN         NaN         NaN         NaN  ...
# 2110            NaN         NaN         NaN         NaN         NaN  ...
# 2276            NaN         NaN         NaN         NaN         NaN  ...
# ...             ...         ...         ...         ...         ...  ...
# 275970          NaN         NaN         NaN         NaN         NaN  ...
# 276680          NaN         NaN         NaN         NaN         7.0  ...
# 277427          NaN         NaN         NaN         NaN         0.0  ...
# 277639          NaN         NaN         NaN         NaN         NaN  ...
# 278188          NaN         NaN         NaN         0.0         NaN  ...
#
# ISBN     0553279912  059035342X  0671003755  0671021001  0671027360  \
# User-ID
# 254             NaN         NaN         NaN         7.0         NaN
# 1733            NaN        10.0         NaN         NaN         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN        10.0         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 275970          NaN         NaN         NaN         NaN         NaN
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         NaN         NaN         NaN
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
#
# ISBN     067976402X  0743418174  0804106304  0971880107  1400034779
# User-ID
# 254             0.0         NaN         0.0         NaN         NaN
# 1733            NaN         NaN         NaN         1.0         NaN
# 2033            NaN         NaN         NaN         NaN         NaN
# 2110            NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 275970          NaN         NaN         NaN         NaN         NaN
# 276680          NaN         NaN         NaN         NaN         NaN
# 277427          NaN         NaN         NaN         0.0         0.0
# 277639          NaN         NaN         NaN         NaN         NaN
# 278188          NaN         NaN         NaN         NaN         NaN
#
# [804 rows x 47 columns]
# User 140358:
# Closest centroid:  3
# The Da Vinci Code;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# To Kill a Mockingbird;
# Where the Heart Is (Oprah's Book Club (Paperback));
# Confessions of a Shopaholic (Summer Display Opportunity);
# Good in Bed;
# The Client;
# Girl with a Pearl Earring;
# 1st to Die: A Novel;
# The Lovely Bones: A Novel
# User 120598:
# Closest centroid:  63
# To Kill a Mockingbird;
# 1st to Die: A Novel;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Where the Heart Is (Oprah's Book Club (Paperback));
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# Good in Bed;
# Girl with a Pearl Earring;
# The Client;
# The Da Vinci Code
# User 265083:
# Closest centroid:  13
# The Da Vinci Code;
# The Lovely Bones: A Novel;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Good in Bed;
# The Secret Life of Bees;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Client
# User 253821:
# Closest centroid:  15
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# 1st to Die: A Novel;
# Good in Bed;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# The Client;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist);
# Life of Pi
# User 83637:
# Closest centroid:  83
# Confessions of a Shopaholic (Summer Display Opportunity);
# To Kill a Mockingbird;
# Good in Bed;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# The Client;
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist);
# Life of Pi
# User 145165:
# Closest centroid:  60
# The Client;
# The Da Vinci Code;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Red Tent (Bestselling Backlist);
# Interview with the Vampire;
# Girl with a Pearl Earring;
# Good in Bed;
# Where the Heart Is (Oprah's Book Club (Paperback));
# To Kill a Mockingbird;
# Confessions of a Shopaholic (Summer Display Opportunity)
# User 200226:
# Closest centroid:  89
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# The Client;
# The Da Vinci Code;
# Interview with the Vampire;
# Life of Pi;
# The Secret Life of Bees
# User 28523:
# Closest centroid:  83
# Confessions of a Shopaholic (Summer Display Opportunity);
# To Kill a Mockingbird;
# Good in Bed;
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# The Client;
# The Da Vinci Code;
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist)
# User 108352:
# Closest centroid:  0
# Confessions of a Shopaholic (Summer Display Opportunity);
# The Client;
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# Where the Heart Is (Oprah's Book Club (Paperback));
# 1st to Die: A Novel;
# To Kill a Mockingbird;
# The Da Vinci Code;
# Interview with the Vampire
# User 236058:
# Closest centroid:  21
# Where the Heart Is (Oprah's Book Club (Paperback));
# Good in Bed;
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback));
# Girl with a Pearl Earring;
# The Client;
# The Da Vinci Code;
# Confessions of a Shopaholic (Summer Display Opportunity);
# Interview with the Vampire;
# The Red Tent (Bestselling Backlist);
# Life of Pi
